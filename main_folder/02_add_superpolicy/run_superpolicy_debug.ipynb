# %%
import sys
sys.path.append('../shared')
from config_loader import load_config
from superpolicy_processor import SuperpolicyProcessor
from superpolicy_diagnostics import SuperpolicyDiagnostics

config = load_config('../config.json')
processor = SuperpolicyProcessor(config)
diag = SuperpolicyDiagnostics()

# %%
processor.load_data()
diag.null_check(processor.df)
# Out:
# Loaded 22,705,842 rows
#   OK policyid: 0
#   OK vin: 0
#   OK vin_date: 0

# %%
processor.consolidate()
# Out:
# Iteration  1: 1,753,681 VINs cross policies
# Iteration  2: 99,741 VINs cross policies
# Iteration  3: 9,699 VINs cross policies
# Iteration  4: 1,409 VINs cross policies
# Iteration  5: 328 VINs cross policies
# Iteration  6: 112 VINs cross policies
# Iteration  7: 46 VINs cross policies
# Iteration  8: 16 VINs cross policies
# Iteration  9: 9 VINs cross policies
# Iteration 10: 6 VINs cross policies
# Iteration 11: 6 VINs cross policies
# Iteration 12: 4 VINs cross policies
# Iteration 13: 0 VINs cross policies -> converged
# Consolidation complete after 14 iterations

# %%
diag.summary_stats(processor.df)
# Out:
# Total Records            :             22705842
# Original Policies        :              9058700
# Consolidated Policies    :              4219001
# Unique VINs              :              6591774
# Policy Reduction         :               53.43%
# {'Total Records': 22705842,
#  'Original Policies': 9058700,
#  'Consolidated Policies': 4219001,
#  'Unique VINs': 6591774,
#  'Policy Reduction': '53.43%'}

# %%
diag.policy_size_distribution(processor.df)
# Out:
# Min:  1
# Max:  889
# Mean: 5
# Median: 4

# %%
df_out = processor.export()
# Out:
# Output saved: /Users/Mach/dev/aps/data/2026_Dmodel_data/superpolicy/superpolicy_car.parquet
# Output shape: (22705842, 2)

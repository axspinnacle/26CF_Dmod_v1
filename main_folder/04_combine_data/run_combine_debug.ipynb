# %%
import sys
sys.path.append('../shared')
from config_loader import load_config
from data_combiner import DataCombiner
from combine_diagnostics import CombineDiagnostics

config = load_config('../config.json')
combiner = DataCombiner(config)
diag = CombineDiagnostics()

# %%
combiner.load_data()
# Out:
# Fold data shape: (22705842, 8)
# Dep factor data shape: (27052200, 12)

# %%
combiner.join()
# Out:
# Joined data shape: (27052200, 19)
# Original dep factor rows: 27,052,200
# Fold data rows: 22,705,842
# Rows with fold match: 27,052,200 (100.00%)
# Rows without fold match: 0 (0.00%)

# %%
diag.compare_shapes(combiner.df_dep, combiner.df_fold, combiner.df_joined)
# Out:
# Dep factor shape:  (27052200, 12)
# Fold shape:        (22705842, 8)
# Joined shape:      (27052200, 19)

# %%
diag.check_join_quality(combiner.df_joined, combiner.join_key)
# Out:
# Total rows: 27,052,200
# Duplicate vin_date values: 4,348,867
#   BODY_STYLE_SEGMENT_BODY_TYPE: 17,469 nulls (0.06%)
#   Dep_factor: 17,469 nulls (0.06%)
#   veh_value_dep: 17,469 nulls (0.06%)
#   pp_bi: 1,428,987 nulls (5.28%)
#   pp_pd: 1,154,631 nulls (4.27%)
#   pp_pip: 17,403,253 nulls (64.33%)
#   pp_coll: 8,676,689 nulls (32.07%)
#   pp_comp: 7,826,068 nulls (28.93%)

# %%
diag.fold_distribution(combiner.df_joined)
# Out:
# fold
# 1     2716120
# 2     2700291
# 3     2705542
# 4     2708064
# 5     2700059
# 6     2707950
# 7     2701212
# 8     2707146
# 9     2706978
# 10    2698838
# Name: count, dtype: int64

# %%
df_out = combiner.export()
# Out:
# Saved joined data: /Users/Mach/dev/aps/data/2026_Dmodel_data/car_with_dep_factor_fold.parquet
